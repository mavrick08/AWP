# %% [markdown]
# * Seaborn is built on top of matplotlib
# * With Seaborn we can create Python Visualization.

# %% [markdown]
# pip install seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
help(sns.load_dataset)
# Out:
# Help on function load_dataset in module seaborn.utils:
#
# load_dataset(name, cache=True, data_home=None, **kws)
#     Load an example dataset from the online repository (requires internet).
#
#     This function provides quick access to a small number of example datasets
#     that are useful for documenting seaborn or generating reproducible examples
#     for bug reports. It is not necessary for normal usage.
#
#     Note that some of the datasets have a small amount of preprocessing applied
#     to define a proper ordering for categorical variables.
#
#     Use :func:`get_dataset_names` to see a list of available datasets.
#
#     Parameters
#     ----------
#     name : str
#         Name of the dataset (``{name}.csv`` on
#         https://github.com/mwaskom/seaborn-data).
#     cache : boolean, optional
#         If True, try to load from the local cache first, and save to the cache
#         if a download is required.
#     data_home : string, optional
# ...

# %%
tips = sns.load_dataset('tips')   #loading the dataset

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style(style='whitegrid')

# %%
sns.lineplot(x='size',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.set_style(style='darkgrid')

# %%
sns.lineplot(x='size',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.set_style(style='dark')
sns.lineplot(x='size',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.set_style(style='white')
sns.lineplot(x='size',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.set_style(style='whitegrid')
sns.scatterplot(x='total_bill',y='tip',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
tips['tip'].mean()
# Out:
# 2.9982786885245902

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.scatterplot(x='total_bill',y='tip',hue='smoker',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip',hue='time',data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x='total_bill',y='tip',hue='time',data=tips)

# %%
# plt.figure(figsize=(6,9))
my_markers = {"Male":"P","Female":"X"}
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=tips,style='sex',markers=my_markers)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
titanic = sns.load_dataset('titanic')
fmri = sns.load_dataset('fmri')
flights = sns.load_dataset('flights')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x='total_bill',y='tip',hue='smoker',data=tips
               ,size="size")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=flights,x='month',y='passengers',kind='line',
           ci=None)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=tips
           ,col='time')

# %%
sns.displot(titanic['age'])

# %%
sns.displot(titanic['age'],kde=True)

# %%
sns.displot(titanic['age'],bins=5)

# %%
sns.histplot(tips,x='day',shrink=0.7)
# Out:
# <AxesSubplot:xlabel='day', ylabel='Count'>

# %%
sns.displot(titanic,x='age',hue='pclass')

# %%
sns.histplot(titanic,x='age',hue='sex')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.set_style('darkgrid')
sns.histplot(titanic,x='age',hue='survived',palette='Reds')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.pairplot(tips)

# %%
sns.pairplot(titanic)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.kdeplot(data=tips,x='tip')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(data=tips,x='tip',hue='day')
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %%
sns.catplot(data=titanic,x='sex',y='survived',hue='class',kind='bar')

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=tips,x='sex',y='total_bill',hue='day')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(data=tips,x='day')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.boxplot(data=tips,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips,x='day',y='total_bill',hue='smoker',kind='box')

# %%
sns.catplot(data=tips,x='day',y='total_bill',hue='smoker')

# %%
sns.swarmplot(data=tips,x='day',y='total_bill')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.lmplot(data=tips,x='total_bill',y='tip')

# %%
data = np.random.randn(10,15)

# %%
data
# Out:
# array([[ 0.19492029, -0.36721117, -0.15079653, -1.08048911, -0.68545881,
#          0.45949726,  0.03861753, -1.12634086, -0.09041451, -0.59671391,
#          0.1494785 ,  0.26851088,  1.38871013, -0.54654441,  1.17165146],
#        [-0.91582341,  0.95493333, -1.00640494,  0.49927187,  0.49196198,
#          0.31970655, -1.34701479,  1.08526339,  1.25318572,  1.77809993,
#          0.70307914, -1.80414905, -0.33463241, -1.60866871,  0.09359193],
#        [ 0.34741172, -0.86434885, -0.05927606, -0.9272918 ,  1.17349326,
#         -1.16981738, -0.81865294, -1.04608519, -0.18741967, -0.60572098,
#         -2.15680908,  1.23923765,  0.5874297 , -0.31888379,  1.38686568],
#        [-1.25910471,  1.70761237,  1.03840866, -0.11712342,  0.66257788,
#         -0.85836452, -0.76928504,  0.52548549, -0.06056028,  0.85968173,
#          1.86948386,  1.76534794,  0.51743329, -0.39861231, -0.85620686],
#        [ 1.2624517 , -0.94547817, -0.16807986,  0.13807261,  0.12346095,
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data,annot=True)
# Out:
# <AxesSubplot:>
